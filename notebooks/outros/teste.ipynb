# %%
from airflow.sdk import dag, task
from datetime import datetime, timedelta
from airflow import DAG
from airflow.operators.python import PythonOperator
from airflow.operators.empty import EmptyOperator
from airflow.models.param import Param, ParamsDict
from sqlalchemy import create_engine, VARCHAR, Integer,Date
import os
import pandas as pd
from datetime import datetime
import zipfile
import numpy as np
from airflow.operators.bash import BashOperator
import requests
# Out:
# c:\Users\Nelio\anaconda3\Lib\site-packages\airflow\__init__.py:45: RuntimeWarning: Airflow currently can be run on POSIX-compliant Operating Systems. For development, it is regularly tested on fairly modern Linux Distros and recent versions of macOS. On Windows you can run it via WSL2 (Windows Subsystem for Linux 2) or via Linux Containers. The work to add Windows support is tracked via https://github.com/apache/airflow/issues/10388, but it is not a high priority.
#   warnings.warn(
# 2026-03-20T14:39:38.101118Z [info     ] setup plugin alembic.autogenerate.schemas [alembic.runtime.plugins] loc=plugins.py:37
# 2026-03-20T14:39:38.108417Z [info     ] setup plugin alembic.autogenerate.tables [alembic.runtime.plugins] loc=plugins.py:37
# 2026-03-20T14:39:38.114773Z [info     ] setup plugin alembic.autogenerate.types [alembic.runtime.plugins] loc=plugins.py:37
# ...

# %%
print("oi")

# %%
pip install sqlalchemy psycopg2-binary pandas

# %%
pip install psycopg2-binary

# %%
import psycopg2

# Conexão com o banco
conn = psycopg2.connect(
    host="localhost",       # porque você expôs a porta 5432
    port="5432",
    database="mydatabase",
    user="postgres",
    password="postgres"
)

# Criar cursor
cur = conn.cursor()

# Criar tabela de exemplo
cur.execute("""
    CREATE TABLE IF NOT EXISTS clientes (
        id SERIAL PRIMARY KEY,
        nome VARCHAR(100),
        email VARCHAR(100)
    )
""")

# Inserir dados
cur.execute("""
    INSERT INTO clientes (nome, email)
    VALUES (%s, %s)
""", ("José", "jnelior@gmail.com"))

# Confirmar transação
conn.commit()

# Consultar dados
cur.execute("SELECT * FROM clientes")
rows = cur.fetchall()
for row in rows:
    print(row)

# Fechar conexão
cur.close()
conn.close()

# %%
from sqlalchemy import create_engine, VARCHAR, Integer,Date
import pandas as pd

# %%
conn = psycopg2.connect(
    host="localhost",       # porque você expôs a porta 5432
    port="5432",
    database="mydatabase",
    user="postgres",
    password="postgres"
)

# %%
# Conexão com o PostgreSQL
engine = create_engine("postgresql+psycopg2://postgres:postgres@localhost:5432/mydatabase")

# %%
df.to_sql("cinema_BR", engine, if_exists="replace", dtype=dtype_map, index=False)

# %%
# Exemplo de DataFrame
df = pd.read_csv(r'C:\Users\Nelio\Documents\GitHub\cinema_prod\data\processados\bilheteria_diaria_tratada.csv', delimiter=';')

# %%
df = df.head(500)
df

# %%
dtype_map = {
    "DATA_EXIBICAO": Date,
    "TITULO_FILME": VARCHAR(255),
    "SESSAO": VARCHAR(255),
    "TITULO_ORIGINAL": VARCHAR(255),
    "TITULO_BRASIL": VARCHAR(255),
    "CPB_ROE": VARCHAR(255),
    "AUDIO": VARCHAR(255),
    "LEGENDADA": VARCHAR(255),
    "PAIS_OBRA": VARCHAR(255),
    "REGISTRO_SALA": VARCHAR(255),
    "NOME_SALA": VARCHAR(255),
    "PUBLICO": Integer,  # único inteiro
    "REGISTRO_GRUPO_EXIBIDOR": Integer,
    "REGISTRO_EXIBIDOR": VARCHAR(255),
    "REGISTRO_COMPLEXO": VARCHAR(255),
    "MUNICIPIO_SALA_COMPLEXO": VARCHAR(255),
    "UF_SALA_COMPLEXO": VARCHAR(255),
    "RAZAO_SOCIAL_EXIBIDORA": VARCHAR(255),
    "CNPJ_EXIBIDORA": VARCHAR(255),
    "NOME_ARQUIVO": VARCHAR(255)
}

# %%
# Subir para o banco
df.to_sql("cinema_BR", engine, if_exists="replace", dtype=dtype_map, index=False)

# %%
import pandas as pd
from sqlalchemy import create_engine, VARCHAR

# Conexão
engine = create_engine("postgresql+psycopg2://postgres:postgres@localhost:5432/mydatabase")

# DataFrame de exemplo
df = pd.DataFrame({
    "nome": ["José", "Maria", "Carlos"],
    "email": ["jose@email.com", "maria@email.com", "carlos@email.com"]
})

# Subir para o banco
df.to_sql(
    name="clientes",
    con=engine,
    schema="public",
    if_exists="replace",
    index=False,
    dtype={"nome": VARCHAR(100), "email": VARCHAR(100)},
    method="multi"
)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\Nelio\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     142 try:
# --> 143     self._dbapi_connection = engine.raw_connection()
#     144 except dialect.loaded_dbapi.Error as err:
#
# File c:\Users\Nelio\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:3301, in Engine.raw_connection(self)
#    3280 """Return a "raw" DBAPI connection from the connection pool.
#    3281
#    3282 The returned object is a proxied version of the DBAPI
#    (...)   3299
#    3300 """
# -> 3301 return self.pool.connect()
#
# File c:\Users\Nelio\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:447, in Pool.connect(self)
#     440 """Return a DBAPI connection from the pool.
#     441
# ...

# %%
def unzip_file(zip_path, file_save, anos=""):

    zip_name = os.path.splitext(os.path.basename(zip_path))[0]
    extract_to = os.path.join(file_save, zip_name)
    os.makedirs(extract_to, exist_ok=True)

    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        print(f"Descompactando: {zip_path} para {extract_to}")
        for file_name in zip_ref.namelist():
            print(f"Verificando arquivo: {file_name} para extração")
            if anos == 'TODOS' or str(anos) in file_name:
                zip_ref.extract(file_name, extract_to)
                print(f"Extraído: {file_name}")

# %%
def read_bilheteria(caminho_arquivo,anos,estados, row, caminho_saida,database, senha, host):     
    print (f"acessando: postgresql+psycopg2://postgres:{senha}@{host}:5432/{database}")
    engine = create_engine(f"postgresql+psycopg2://postgres:nelio@{host}:5432/{database}")
        ##172.20.0.3
    dataframe = []
    colunas_datas = ['DATA_EXIBICAO', 'SESSAO']
    colunas_inteiros = ['PUBLICO']
    for arquivo in os.listdir(caminho_arquivo):
        if arquivo.endswith('.csv') and anos == "" or str(anos) in arquivo:
            caminho_completo = os.path.join(caminho_arquivo, arquivo)
            print(f"Processando arquivo: {caminho_completo}")
            df = pd.read_csv(caminho_completo, delimiter=';', dtype=str)
            df['NOME_ARQUIVO'] = arquivo
            if estados:
                df = df[df['UF_SALA_COMPLEXO'] == estados]
            df['TITULO_FILME'] = df['TITULO_BRASIL'].fillna(df['TITULO_ORIGINAL'])
            df.insert(1, 'TITULO_FILME', df.pop('TITULO_FILME'))
            df = df[df['REGISTRO_SALA'].notnull()]
            for coluna in colunas_datas:
                df[coluna] = pd.to_datetime(df[coluna], errors='coerce', dayfirst=True)
            for coluna in colunas_inteiros:
                df[coluna] = pd.to_numeric(df[coluna], errors='coerce').fillna(0).astype(int)
            df.columns = [col.lower() for col in df.columns]
            df.to_sql("bilheteria", engine, index=False, if_exists='append')
            print(f"Arquivo Carregado no Bando de dados: {arquivo}")

            dataframe.append(df)

    df_bilheteria = pd.concat(dataframe, ignore_index=True)     


    nome_arquivo_saida = os.path.join(caminho_saida, "bilheteria_diaria_tratada.csv")
    df_bilheteria.to_csv(nome_arquivo_saida, sep=';', index=False, encoding='utf-8')
    print(f"Salvo com sucesso em: {nome_arquivo_saida}")

# %%
etl_bilheteria =  read_bilheteria(
    caminho_arquivo = r"C:\Users\Nelio\OneDrive\_CINEMA\cinema_2026\data\raw\unzip\bilheteria-diaria\bilheteria-diaria-obras-por-exibidoras-csv",
    anos = "",
    estados = "",
    row= None,
    caminho_saida = r"C:\Users\Nelio\OneDrive\_CINEMA\cinema_2026\data\processados"
    ,database = "cinema_teste"
    ,host="localhost"
    ,senha="postgres"
    )
# Out:
# acessando: postgresql+psycopg2://postgres:postgres@localhost:5432/cinema_teste
# Processando arquivo: C:\Users\Nelio\OneDrive\_CINEMA\cinema_2026\data\raw\unzip\bilheteria-diaria\bilheteria-diaria-obras-por-exibidoras-csv\bilheteria-diaria-obras-por-exibidoras-2014-06-s01.csv
# Arquivo Carregado no Bando de dados: bilheteria-diaria-obras-por-exibidoras-2014-06-s01.csv
# Processando arquivo: C:\Users\Nelio\OneDrive\_CINEMA\cinema_2026\data\raw\unzip\bilheteria-diaria\bilheteria-diaria-obras-por-exibidoras-csv\bilheteria-diaria-obras-por-exibidoras-2014-06-s02.csv
# Arquivo Carregado no Bando de dados: bilheteria-diaria-obras-por-exibidoras-2014-06-s02.csv
# Processando arquivo: C:\Users\Nelio\OneDrive\_CINEMA\cinema_2026\data\raw\unzip\bilheteria-diaria\bilheteria-diaria-obras-por-exibidoras-csv\bilheteria-diaria-obras-por-exibidoras-2014-06-s03.csv
# Arquivo Carregado no Bando de dados: bilheteria-diaria-obras-por-exibidoras-2014-06-s03.csv
# ...

# %%
unzipbilheteria = unzip_file(
    zip_path = r"C:\Users\Nelio\OneDrive\_CINEMA\cinema_2026\data\raw\zip\bilheteria_diaria\bilheteria-diaria-obras-por-exibidoras-csv.zip",
    file_save=r"C:\Users\Nelio\OneDrive\_CINEMA\cinema_2026\data\raw\unzip\bilheteria-diaria",
    anos = ""
)
# Out:
# Descompactando: C:\Users\Nelio\OneDrive\_CINEMA\cinema_2026\data\raw\zip\bilheteria_diaria\bilheteria-diaria-obras-por-exibidoras-csv.zip para C:\Users\Nelio\OneDrive\_CINEMA\cinema_2026\data\raw\unzip\bilheteria-diaria\bilheteria-diaria-obras-por-exibidoras-csv
# Verificando arquivo: bilheteria-diaria-obras-por-exibidoras-2014-06-s01.csv para extração
# Extraído: bilheteria-diaria-obras-por-exibidoras-2014-06-s01.csv
# Verificando arquivo: bilheteria-diaria-obras-por-exibidoras-2014-06-s02.csv para extração
# Extraído: bilheteria-diaria-obras-por-exibidoras-2014-06-s02.csv
# Verificando arquivo: bilheteria-diaria-obras-por-exibidoras-2014-06-s03.csv para extração
# Extraído: bilheteria-diaria-obras-por-exibidoras-2014-06-s03.csv
# Verificando arquivo: bilheteria-diaria-obras-por-exibidoras-2014-06-s04.csv para extração
# Extraído: bilheteria-diaria-obras-por-exibidoras-2014-06-s04.csv
# Verificando arquivo: bilheteria-diaria-obras-por-exibidoras-2014-06-s05.csv para extração
# ...

# %%
# Out:
# acessando: postgresql+psycopg2://postgres:postgres@localhost:5432/cinema_teste
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 etl_bilheteria =  read_bilheteria(
#       2             caminho_arquivo = r"C:\Users\Nelio\OneDrive\_CINEMA\cinema_2026\data\raw\unzip\bilheteria-diaria\bilheteria-diaria-obras-por-exibidoras-csv",
#       3             anos = '2026',
#       4             estados = "RR",
#       5             row= None,
#       6             caminho_saida = r"C:\Users\Nelio\OneDrive\_CINEMA\cinema_2026\data\raw\unzip\bilheteria-diaria\bilheteria-diaria-obras-por-exibidoras-csv"
#       7             ,database = "cinema_teste"
#       8             ,host="localhost"#"172.19.0.2"
#       9             ,senha="postgres"
#      10             )
#
# ...
